# %% [markdown]
# #### Import do módulo `jupyturtle`

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Download realizado: " + str(local))
    return filename

download('https://github.com/ramalho/jupyturtle/releases/download/2024-03/jupyturtle.py');
# Out:
# Download realizado: jupyturtle.py

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Exercício 1
#
# Escreva uma função chamada `rectangle` que desenhe um retângulo com os comprimentos de lado especificados. Por exemplo, aqui está um retângulo com `80` unidades de largura e `40` unidades de altura.
#
# Exemplo:
#
# ```
# make_turtle()
# rectangle(80, 40)
# ```
#
# Dica: não esqueça de importar o módulo `jupyturtle` antes de executar seu código

# %%
from jupyturtle import *

def rectangle(largura: int, altura: int):
  make_turtle()
  for _ in range(2):
    fd(largura)
    rt(90)
    fd(altura)
    rt(90)

largura = int(input('Digite a largura do retangulo: '))
altura = int(input('Digite a altura do retangulo: '))
rectangle(largura, altura)
# Out:
# Digite a largura do retangulo: 1000
# Digite a altura do retangulo: 12
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="1150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="1150.0" y1="75.0" x2="1150.0" y2="87.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="1150.0" y1="87.0" x2="150.0" y2="87.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="150.0" y1="87.0" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercício 2
#
# Escreva uma função chamada `losango` que desenhe um losango com um determinado comprimento de lado e um determinado ângulo interno. Por exemplo, aqui está um losango com comprimento de lado 50 e ângulo interno de 60 graus.
#
# Exemplo:
#
# ```
# make_turtle()
# losango(80, 40)
# ```
#
# Dica: não esqueça de importar o módulo `jupyturtle` antes de executar seu código

# %%
def losango(lado: int, angulo1: int, angulo2: int):
  make_turtle()
  for _ in range(2):
    fd(lado)
    rt(angulo1)
    fd(lado)
    rt(angulo2)

lado = int(input('Digite o tamanho do lado do losango: '))
angulo1 = int(input('Digite o primeiro ângulo do losango (ângulo tem que ser menor do que 180°): '))
angulo2 = int(input('Digite o segundo ângulo do losango (ex: 180 - primeiro angulo): '))
losango(lado, angulo1, angulo2)
# Out:
# Digite o tamanho do lado do losango: 160
# Digite o primeiro ângulo do losango (ângulo tem que ser menor do que 180°): 160
# Digite o segundo ângulo do losango (ex: 180 - primeiro angulo): 20
# <svg width="300" height="150">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
# <line x1="150" y1="75" x2="310.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
# <line x1="310.0" y1="75.0" x2="159.6" y2="129.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="159.6" y1="129.7" x2="-0.4" y2="129.7"
#     stroke="#663399" stroke-width="2" />
# <line x1="-0.4" y1="129.7" x2="150.0" y2="75.0"
#     stroke="#663399" stroke-width="2" />
#
# <g transform="rotate(-90.0,150.0,75.0) translate(150.0, 75.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %% [markdown]
# ### Exercício 3
#
# Escreva um programa que simule uma partida de Pedra, Papel e Tesoura entre o usuário e o computador.
#
# O programa deve ler a jogada do usuário (rock, paper ou scissors), sortear a jogada do computador entre as mesmas opções e exibir o resultado da partida (vitória, derrota ou empate), seguindo as regras clássicas: pedra vence tesoura, tesoura vence papel, papel vence pedra.
#
# Exemplo:
#
# ```
# Escolha pedra, papel ou tesoure: pedra
# Você escolheu: pedra
# Computador escolheu: tesoura
# Você venceu! 🎉
# ```
#
# Dica: use `random.choice` para sortear a jogada do computador e combine as comparações de vitória em uma única estrutura `if/elif/else` com os operadores `and/or`.

# %%
import random

def rock_paper_scissors(usuario1, usuario2):
  if usuario1 == usuario2:
    print('Empate!! ')
  elif(usuario1 == 'pedra' and usuario2 == 'tesoura' or usuario1 == 'papel' and usuario2 == 'pedra' or usuario1 == 'tesoura' and usuario2 == 'papel'):
    print('Você venceu!!!! ')
  else:
    print('Você perdeu!!!! ')

opcoes = ['pedra', 'papel', 'tesoura']
jogada = input('Escolha: pedra, papel ou tesoura ')
pc = random.choice(opcoes)
print(f'Você escolheu: {jogada}')
print(f'O computador escolheu: {pc}')
rock_paper_scissors(jogada, pc)
# Out:
# Escolha: pedra, papel ou tesoura pedra
# Você escolheu: pedra
# O computador escolheu: papel
# Você perdeu!!!!

# %% [markdown]
# ### Exercício 4
#
# Escreva um programa que aplique um pequeno quiz de 3 perguntas ao usuário, contabilizando os acertos em uma variável `score`.
#
# Perguntas e respostas esperadas:
#
# ```
# Qual a capital da França? → Paris
# O que a sigla CPU significa? → deve conter a expressão Central Processing Unit
# Qual a linguagem de programação utilizada na disciplina? → Python
# ```
#
# Para cada pergunta, leia a resposta do usuário, compare (ignorando espaços extras e diferenças entre maiúsculas/minúsculas) e exiba "Correto!" ou a mensagem informando a resposta correta. Ao final, exiba a pontuação total.
#
# Exemplo:
#
# ```
# Qual a capital da França? paris
# Correto!
# O que a sigla CPU significa? central processing unit
# Correto!
# Qual a linguagem de programação utilizada na disciplina? java
# Incorreta. A resposta é Python.
#
# Seu score final: 2/3
# ```
#
# Dica: use `.strip()` e `.lower()` para normalizar a entrada, `==` para comparações exatas e o operador `in` para verificar se uma expressão está contida na resposta.

# %%
def quiz():
  score: int = 0
  resp1 = input('Qual a capital da França? ').strip().lower()
  if resp1 == 'paris':
    print('Resposta correta!')
    score += 1
  else:
    print('Incorreta. A resposta é Paris.')
  resp2 = input('O que a sigla CPU significa? (Somente a expressão) ').strip().lower()
  if resp2 == 'central processing unit':
    print('Resposta correta!')
    score += 1
  else:
    print('Incorreta. A resposta é central processing unit.')
  resp3 = input('Qual a linguagem de programção utilizada na disciplina? ')
  if resp3 == 'python':
    print('Resposta correta!')
    score += 1
  else:
    print('Incorreta. A resposta é python.')
  print(f"Seu score final: {score} /3")


quiz()
# Out:
# Qual a capital da França? uber
# Incorreta. A resposta é Paris.
# O que a sigla CPU significa? (Somente a expressão) sla
# Incorreta. A resposta é central processing unit.
# Qual a linguagem de programção utilizada na disciplina? python
# Resposta correta!
# Seu score final: 1 /3

# %% [markdown]
# ### Exercício 5
#
# Escreva um programa que sorteie uma palavra embaralhada e peça ao usuário para adivinhar a palavra original, repetindo a pergunta até que ele acerte ou digite `quit` para desistir.
#
# Use a palavra `python`, embaralhe suas letras e exiba o resultado para o usuário. Em seguida, entre em um laço que lê a tentativa do usuário: se for `quit`, exiba a palavra correta e encerre; se for igual à palavra original, exiba uma mensagem de acerto e encerre; caso contrário, informe que a tentativa está errada e peça uma nova.
#
# Exemplo:
# ```
# Desembaralhe esta palavra: thopyn
# Sua tentativa (ou digite 'quit' para sair): tyhon
# Não foi dessa vez, tente novamente!
# Sua tentativa (ou digite 'quit' para sair): python
# 🎉 Você acertou!
# ```
#
# Dica: use `random.sample` para embaralhar as letras da palavra e `''.join()` para transformar o resultado de volta em string; use `while True` com `break` para controlar a repetição.

# %%
def desembaralhar():
  palavra = 'python'
  palavra_embaralhada = random.sample(palavra, len(palavra))
  palavra_embaralhada = "".join(palavra_embaralhada)
  print(f'Desembaralhe a seguinte palavra: {palavra_embaralhada}')
  while True:
    tentativa = input("Digite a sua tentativa (ou digite 'quit' para sair): ").strip().lower()

    if tentativa == 'quit':
      print(f"A palavra correta era: {palavra}")
      break
    elif tentativa == palavra:
      print('Você acertou!!')
      break
    else:
      print('Não foi dessa vez, tente novamente!')


desembaralhar()
# Out:
# Desembaralhe a seguinte palavra: onptyh
# Digite a sua tentativa (ou digite 'quit' para sair): quit
# A palavra correta era: python

# %% [markdown]
# ### Exercício 6
#
# Desenvolva um programa que selecione um número aleatório entre 0 e 100. O usuário deverá tentar adivinhar esse número, recebendo uma dica ("maior" ou "menor") a cada tentativa incorreta. Ao final, o programa exibirá a sequência de palpites do usuário e o total de tentativas feitas até acertar o número correto.
#
# Exemplo:
# ```
# Digite um número: 50
# O número correto é menor que este
# Digite um número: 25
# O número correto é maior que este
# Digite um número: 37
# Parabéns você acertou!
# Os seus chutes foram: 50 25 37
# O total de chutes foram:  3
# ```
#
# Dica: use `random.randint` para sortear o número, uma lista para armazenar os palpites e um laço `while True` com `break/continue` para controlar as tentativas.

# %%
def acerta_num():
  num_aleatorio = random.randint(0, 100)
  palpites = []
  while True:
    tentativa = int(input('Digite um número: '))
    palpites.append(tentativa)
    if tentativa == num_aleatorio:
      print('Parabéns você acertou!')
      break
    elif tentativa > num_aleatorio:
      print(f"O número correto é menor que {tentativa}")
    else:
      print(f"O número correto é maior que {tentativa}")
  print("Os seus chutes foram: ", *palpites)
  print("O total de chutes foram: ", len(palpites))


acerta_num()
# Out:
# Digite um número: 50
# O número correto é maior que 50
# Digite um número: 80
# O número correto é menor que 80
# Digite um número: 60
# O número correto é maior que 60
# Digite um número: 70
# O número correto é maior que 70
# Digite um número: 75
# O número correto é maior que 75
# Digite um número: 79
# Parabéns você acertou!
# Os seus chutes foram:  50 80 60 70 75 79
# O total de chutes foram:  6
